# %% [markdown]
# # LEAFToolbox for Sites
# Applies the LEAF-ToolBox for mapping vegetation using satellite imagery over a list of sites, each defined using time stamped vector geographical objects.
# Cite as Fernandes, R. et al., 2021, "LEAF Toolbox", Canada Centre for Remote Sensing, https://github.com/rfernand387/LEAF-Toolbox/wiki, DOI: 10.5281/zenodo.4321298.
#
#
# LEAF currently supports two algorithms:
#
# SL2PV0 is the algorithm defined by Weiss and Baret (2016) with an update in Weiss and Baret (2020).
#
#
# SL2PV1.1 defined in  Fernandes et al. 2024 that attempts to correct for biases in crown and shoot clumping over forests observed in SL2PV0.
#
#
# Refer to https://github.com/rfernand387/LEAF-Toolbox/tree/master/Source-Python for configuration of anaconda environment.
#
#
# Weiss, M. and Baret, F. 2016. S2ToolBox Level 2 products: LAI, FAPAR, FCOVER, 1.1. ed.
# Institut National de la Recherche Agronomique, Avignon, France. https://step.esa.
# int/docs/extra/ATBD_S2ToolBox_L2B_V1.1.pdf.
#
# Weiss, M., and Baret, F., 2020. S2ToolBox Level 2 Products: LAI, FAPAR, FCOVER, 2.0. ed.
# Institut National de la Recherche Agronomique, Avignon, France. https://step.esa.
# int/docs/extra/ATBD_S2ToolBox_L2B_V2.0.pdf.
#
# Fernandes, R., Canisius, F., Harvey, K., Hong, G., MacDougall, C., Shah, H., Sun, L., 2024. Evidence of a bias-variance trade off when correcting for bias in Sentinel 2 forest LAI retrievals using radiative transfer models. Remote Sensing of EnvironmentRemote Sens. Environ. 305. doi:10.1016/j.rse.2024.114060.

# %% [markdown]
# ## Setup Environment

# %%
# Provide your GEE authentificaton
import ee
ee.Authenticate()
# Out:
# <p>To authorize access needed by Earth Engine, open the following
#         URL in a web browser and follow the instructions:</p>
#         <p><a href=https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=h5he54JUiiqickhetaJPg0ehjDLoCUV994Bt2YZmXTw&tc=F4IVH-nJ-hjw6-OutxmYUQBpgOrF7mx3DrtJ4NkaTlU&cc=yf4X9KUTlQORJD9lWKWJLlkDSMkzjb1V7XRYevtJqB4>https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=h5he54JUiiqickhetaJPg0ehjDLoCUV994Bt2YZmXTw&tc=F4IVH-nJ-hjw6-OutxmYUQBpgOrF7mx3DrtJ4NkaTlU&cc=yf4X9KUTlQORJD9lWKWJLlkDSMkzjb1V7XRYevtJqB4</a></p>
#         <p>The authorization workflow will generate a code, which you should paste in the box below.</p>
# Enter verification code:  4/1ATX87lNdlTnu7_3QC14rClvDuRXKOVBJgqp69xEgNjR5H_maQE3TsWP-JVM
# Successfully saved authorization token.

# %%
ee.Initialize()

# %%
# Uncomment this if you are modifying modules
# %load_ext autoreload
# %autoreload 2

# %%
# import LEAF modules
import LEAFv3

# # import algorithm definitions
import SL2PV0 
import SL2PV1
import SL2PV1MIX
import SL2PV1DBF
import SL2PV1ENF
import SL2PV10MIX
import SL2PV10DBF
import SL2PV10ENF

# %%
import LEAFv4

# %%
pip install geetools
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Process Sites with output as a Pandas Data Frame
#
# Sites correspond to readable Google Earth Engine Feature collections under which samples will be extracted.
# If the features have time stamps as properties the sampling interval can be restricted on a feature by feature basis.
# Otherwise the sampling interval must be specified the same for all features.

# %%
# List of GEE feature collections
# siteList = ["projects/ee-modis250/assets/sl2pclass100kmveg20mbuf"]
# siteList=["projects/ee-modis250/assets/FO_HWSW_Buf60_lonlat"]
# siteList=["projects/ee-modis250/assets/northern_filtered_abandoned_wells","projects/ee-modis250/assets/northern_reference_buffers_matched"]
# siteList=["projects/ee-modis250/assets/sample_wells","projects/ee-modis250/assets/sample_wells_reference_buffers"]
siteList=['projects/ee-modis250/assets/2bt/Bonney_SiteswithDates_2019']
# siteList=["projects/ee-modis250/assets/sites_3013_buffer150m"]
# siteList=["projects/ee-ronnyale/assets/random_sample_1000_filtered_abandoned_wells"]
# siteList=["projects/ee-modis250/assets/Anderson/Anderson_LAI-2017-2018_May16to24","projects/ee-modis250/assets/Anderson/Anderson_LAI-2017-2018_Aug16to24"]

# %% [markdown]
# ## Run LEAF

# %%
# Function definition
#
# LEAF.sampleSites
# def sampleSites(siteList,
#                 imageCollectionName,
#                 sensorName,
#                 outputPath,
#                 algorithm,
#                 variableName='Surface_Reflectance',
#                 featureRange=[0,np.nan],
#                 maxCloudcover=100,
#                 outputScale=30,
#                 exportFlag='Asset',
#                 prefixProperty='system:index',
#                 inputScale=30,
#                 bufferSpatialSize=0,
#                 subsamplingFraction=1,
#                 numPixels=0,
#                 geometries=False,
#                 bufferTemporalSize=[0,0],
#                 calendarRange=[1,12,'month'],
#                 timeZone='Etc/GMT+6',
#                 shardSize='ys'
#                 )
#
# Applies a LEAF toolbox algorithm to map a canopy variable for all clear sky unmasked pixels from an input image collection
# falling within the spatial and temporal extents of features in a list of sites.  The spatial extent of features is defined by their GEE geometry.  
# The temporal extent of features is defined by their "system:time_start" and "system:time_end" properties or user defined otherwise.
#
# Parameters:
#
# siteList: list of readable GEE feature collection assets.  Features must have a system:time_start and system:time_end property.
# sensorName: user provided name of sensor for output file name
# imageCollectionName: input image collection name from one of the list defined by GEE
#                 ["COPERNICUS/S2_SR_HARMONIZED","COPERNICUS/S2_SR_HARMONIZED_10m","LANDSAT/LC08/C02/T1_L2","LANDSAT/LC09/C02/T1_L2","NASA/HLS/HLSL30/v002"]
# outputPath: google drive , cloud or gee asset folder (for cloud or asset it must exist)
# algorithm: python module specifying LEAF algorithm to apply , currently one of list ["SL2PV0","SL2PV1"]
# variableName: variable to be mapped from one of the list ["ALBEDO","FAPAR","FCOVER","LAI","CWC","CCC","DASF"] defined by https://github.com/rfernand387/LEAF-Toolbox/wiki/Visualisation-Outputs              
# feature_range: range of features in each site GEE feature collection to sample, use this if you have one site with many features and want only a few of them                                                                                                                        
# maxCloudCover: maximum input image cloud cover percentage [0,100]
# outputScale: output pixel size (m)
# exportFlag: export destination (Local,Drive,Asset,CloudStorage) , dont use Local unless it is a small job
# prefixProperty: the property of the sampling features to use for file name prefix
# inputScale: input pixel size (m)
# bufferSpatialSize: width (m) of spatial buffer applied to features prior to sampling
# bufferTemporalSize: dilation (d) of start and end time of sampled features OR temporal interval ["YYYY-MM-DD","YYYY-MM-DD"[ of start and end of time interval to sample.  
# subsamplingFraction: fraction (0 to 1) of pixels to sample within a feature on any given image
# numPixels: maximum number of pixels to sample within a feature, overrides subsampling fraction
# geometries: export the geometry of the sampling feature
# calendarRange: months within each year to sample, inclusive
# timeZone: time zone for sampling if desired, otherwise UTC
# shardSize: temporal interval of shards for output files, e.g. annual
#
# Output:
#
# Drive,Asset,CloudStorage: .csv file with one row per sampled output pixel per day
# Local: Results in a .pkl file with a pandas dictionary for each site in siteList:
#
# sitesDictionary: dictionary with keys corresponding to sites and structure.  The value of each key is a dictionary with two keys:
#                     'feature' : properties of the sampled feature
#                     'SL2PV0' or 'SL2PV1' : a pandas data frame where columns correspond to algorithm output properties and rows correspond to a retrieval within the time and spatial interval of the feature               
#
# Example:
#S2LAIV0_2025= LEAFv4.sampleSites(siteList, 
# sensorName = 'S2', 
# imageCollectionName="COPERNICUS/S2_SR_HARMONIZED",
# outputPath='leafoutput13',
# algorithm=SL2PV0, 
# variableName="LAI",
# featureRange=[0,999], 
# maxCloudcover=20,
# outputScale=20,
# exportFlag='Drive',
# prefixProperty='system:index',
# inputScale=20,
# bufferSpatialSize=0,
# subsamplingFraction=1,
# numPixels=0,
# geometries=False,
# bufferTemporalSize=['2017-04-01','2025-12-31'],
# calendarRange=[6,9,'month'],
# timeZone='Etc/GMT+6',
# shardSize='YS')
#

# %%
S2LAIV0_2025= LEAFv4.sampleSites(siteList, 
                                    sensorName = 'S2', 
                                    imageCollectionName="COPERNICUS/S2_SR_HARMONIZED",
                                    outputPath='leafoutput13',
                                    algorithm=SL2PV0, \
                                    variableName="LAI",
                                    featureRange=[0,999], 
                                    maxCloudcover=20,
                                    outputScale=20,
                                    exportFlag='Drive',
                                    prefixProperty='system:index',
                                    inputScale=20,
                                    bufferSpatialSize=0,
                                    subsamplingFraction=1,
                                    numPixels=0,
                                    geometries=False,
                                    bufferTemporalSize=['2017-04-01','2025-12-31'],
                                    calendarRange=[6,9,'month'],
                                    timeZone='Etc/GMT+6',
                                    shardSize='YS')
# Out:
# STARTING LEAF.sampleSites using  COPERNICUS/S2_SR_HARMONIZED
# Site:  projects/ee-modis250/assets/2bt/Bonney_SiteswithDates_2019  with  27  features.
# Processing Features: from 0 to 27
# Feature n°: 0/27  -- startDate: 2017-04-01 00:00:00 -- endDate: 2025-12-31 00:00:00
# ----------------------------------------------------------------------------------------------------------
# Sampling from  2017-04-01 00:00:00  to  2018-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: 3C6FL5VAT7H47VOPPX7V62CI
# Sampling from  2018-01-01 00:00:00  to  2019-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: LBK3KPIXXKRWJDYFXX2O62QL
# Sampling from  2019-01-01 00:00:00  to  2020-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: 2ZKN2DDYTBNBV7M454UD6UN5
# Sampling from  2020-01-01 00:00:00  to  2021-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: HJFO42PZMVD4S7VEJ2JYN4DO
# Sampling from  2021-01-01 00:00:00  to  2022-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: 5LH5DDV2STZHLQ4YN5K36RQF
# Sampling from  2022-01-01 00:00:00  to  2023-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: QKKD6CKL3JWDTPKGZ2B7DAP4
# Sampling from  2023-01-01 00:00:00  to  2024-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: SRSSTOZJ47I4AE3UURVCCWYL
# Sampling from  2024-01-01 00:00:00  to  2025-12-31 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: 3GWMMKYDNJXMG2JEX6BAOLGD
# Feature n°: 1/27  -- startDate: 2017-04-01 00:00:00 -- endDate: 2025-12-31 00:00:00
# ----------------------------------------------------------------------------------------------------------
# Sampling from  2017-04-01 00:00:00  to  2018-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: 4XRZ6DWV4BFINVNR2NM722LT
# Sampling from  2018-01-01 00:00:00  to  2019-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: QZRWW5YOX3SVOZRUFXP2THP5
# Sampling from  2019-01-01 00:00:00  to  2020-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: QH6SJMNHKJU2VU2FS2BMGCQY
# Sampling from  2020-01-01 00:00:00  to  2021-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: D3422DIPXJVOA6NNTPJYYWNL
# Sampling from  2021-01-01 00:00:00  to  2022-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: NYJH6O3ZHXS4CXN4S5TYC6NK
# Sampling from  2022-01-01 00:00:00  to  2023-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: NVBP3VCQJ73IWGO6P64LCZB6
# Sampling from  2023-01-01 00:00:00  to  2024-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: FRJ5SQHPFRK7DHZFBEBPIBVH
# Sampling from  2024-01-01 00:00:00  to  2025-12-31 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: AYG7CRWF5WBELLKL6XSI37I5
# Feature n°: 2/27  -- startDate: 2017-04-01 00:00:00 -- endDate: 2025-12-31 00:00:00
# ----------------------------------------------------------------------------------------------------------
# Sampling from  2017-04-01 00:00:00  to  2018-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: 25O566RQEUU2CCOHQA5AMHVF
# Sampling from  2018-01-01 00:00:00  to  2019-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: FFDQLSJK5MWXMPK2IHM73OWF
# Sampling from  2019-01-01 00:00:00  to  2020-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: M4D666LVSKD6XYDWLSMERA3P
# Sampling from  2020-01-01 00:00:00  to  2021-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: FPI26KOHJBQL6VQ5YN2I6ZZX
# Sampling from  2021-01-01 00:00:00  to  2022-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: ZDL5MP7UWFZ2PRQF7JCCA2UR
# Sampling from  2022-01-01 00:00:00  to  2023-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: ZXKWHIGKY64INJH7UP25474Z
# Sampling from  2023-01-01 00:00:00  to  2024-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: SU6BG3DKH64TZZKZSABPG7KT
# Sampling from  2024-01-01 00:00:00  to  2025-12-31 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: SCD4AF4SHQ5XQ4D4QL5JPDVU
# Feature n°: 3/27  -- startDate: 2017-04-01 00:00:00 -- endDate: 2025-12-31 00:00:00
# ----------------------------------------------------------------------------------------------------------
# Sampling from  2017-04-01 00:00:00  to  2018-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: YXEKEGVPSXLZY7AMFNJQCRCU
# Sampling from  2018-01-01 00:00:00  to  2019-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: N6UKXSQWZ67EPQNEKIP3ZV4J
# Sampling from  2019-01-01 00:00:00  to  2020-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: DTSSAEG4N4BDWNIPXK5M5Z4N
# Sampling from  2020-01-01 00:00:00  to  2021-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: G36KQAAOUQC7QKVW347KUS4X
# Sampling from  2021-01-01 00:00:00  to  2022-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: R43Y2PCMVWDGRPLQKEYEMYAR
# Sampling from  2022-01-01 00:00:00  to  2023-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: SIZMGBQHQN3VZ2AC3ZV2T55Z
# Sampling from  2023-01-01 00:00:00  to  2024-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: LUQCCWTCUVAZABDCEPFEZCMJ
# Sampling from  2024-01-01 00:00:00  to  2025-12-31 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: PFCNQWHHLBIG6CS3EF7O4U4I
# Feature n°: 4/27  -- startDate: 2017-04-01 00:00:00 -- endDate: 2025-12-31 00:00:00
# ----------------------------------------------------------------------------------------------------------
# Sampling from  2017-04-01 00:00:00  to  2018-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: BM5C2BFHYRDJTP3VZNRA42OJ
# Sampling from  2018-01-01 00:00:00  to  2019-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: CSZD3NGQLXWB5JSDN6N33YJ3
# Sampling from  2019-01-01 00:00:00  to  2020-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: 4AMTGKI4MYRJJ3KPPGTSNAA3
# Sampling from  2020-01-01 00:00:00  to  2021-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: FQ3Q6MRICHQTGADWL6JRGOAI
# Sampling from  2021-01-01 00:00:00  to  2022-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: BFNMVBCDR2HZTHOAKRXOEWHG
# Sampling from  2022-01-01 00:00:00  to  2023-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: VP7AR4BTIDN2IYEGFBHTWTIS
# Sampling from  2023-01-01 00:00:00  to  2024-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: 2PJQERDQQOBWPPDC7DAY6RIQ
# Sampling from  2024-01-01 00:00:00  to  2025-12-31 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: UGV4R4L2JPZXC2O46MVGBQZZ
# Feature n°: 5/27  -- startDate: 2017-04-01 00:00:00 -- endDate: 2025-12-31 00:00:00
# ----------------------------------------------------------------------------------------------------------
# Sampling from  2017-04-01 00:00:00  to  2018-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: 6RU6FJY3GT7OAH6UPIYWLRG7
# Sampling from  2018-01-01 00:00:00  to  2019-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: NRG3BMUB2DPVQ3CDLZGJXVAZ
# Sampling from  2019-01-01 00:00:00  to  2020-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: E2ABCUHYA3Y5U3M46HIMDN4M
# Sampling from  2020-01-01 00:00:00  to  2021-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: PSABCBUUZDA2RBEPOCNVMJL5
# Sampling from  2021-01-01 00:00:00  to  2022-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: IKAX4PQWCQYC7JUM34LGQCQP
# Sampling from  2022-01-01 00:00:00  to  2023-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: 7DI3RT3RQFVZ7I2BPXHIQL3I
# Sampling from  2023-01-01 00:00:00  to  2024-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: LZUAYH5TGVBHLDICIGCCOZK7
# Sampling from  2024-01-01 00:00:00  to  2025-12-31 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: P7ITKCQDLI3OKAODDKUP42YD
# Feature n°: 6/27  -- startDate: 2017-04-01 00:00:00 -- endDate: 2025-12-31 00:00:00
# ----------------------------------------------------------------------------------------------------------
# Sampling from  2017-04-01 00:00:00  to  2018-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: UVP2AYPKUBUIXARL5WAIXPZ5
# Sampling from  2018-01-01 00:00:00  to  2019-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: X2PWKUKJAS3JJQJPSGJEEZNK
# Sampling from  2019-01-01 00:00:00  to  2020-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: HFLTEX4OIJC3N6XMDGLQANIZ
# Sampling from  2020-01-01 00:00:00  to  2021-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: FIKHUUYZZAPULBLLAZBS552U
# Sampling from  2021-01-01 00:00:00  to  2022-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: MTTLVWKLKZLNLT53LMFKMHOM
# Sampling from  2022-01-01 00:00:00  to  2023-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: HUQTOJ4GBCVMAWEE2BGPO22N
# Sampling from  2023-01-01 00:00:00  to  2024-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: W2NO4N2KGDNDFD4WYJNBEFVV
# Sampling from  2024-01-01 00:00:00  to  2025-12-31 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: 7MTKOTCWM57AJQGPLUFNUMZO
# Feature n°: 7/27  -- startDate: 2017-04-01 00:00:00 -- endDate: 2025-12-31 00:00:00
# ----------------------------------------------------------------------------------------------------------
# Sampling from  2017-04-01 00:00:00  to  2018-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: OEZ7TQMQEOFIFKDDDIAMBN5Q
# Sampling from  2018-01-01 00:00:00  to  2019-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: NWSFOJCTDXAMIINJADBABZA4
# Sampling from  2019-01-01 00:00:00  to  2020-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: SAZAO45FQ4LM3VLXZ5DFAG47
# Sampling from  2020-01-01 00:00:00  to  2021-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: VALKHJSN2DIEEMWZ3MKVGOE7
# Sampling from  2021-01-01 00:00:00  to  2022-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: UWTQON2LWSRROJ5PLPEZUEUI
# Sampling from  2022-01-01 00:00:00  to  2023-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: QCBOYRY6XZBMRTTMKXFWSC6O
# Sampling from  2023-01-01 00:00:00  to  2024-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: 5INOUZUO3BYBWY2ZNEFERAS3
# Sampling from  2024-01-01 00:00:00  to  2025-12-31 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: WHUPM5X4M7TEQDGZWR22XK7K
# Feature n°: 8/27  -- startDate: 2017-04-01 00:00:00 -- endDate: 2025-12-31 00:00:00
# ----------------------------------------------------------------------------------------------------------
# Sampling from  2017-04-01 00:00:00  to  2018-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: H4OSWYA43ZEPAZU75KPAWHRR
# Sampling from  2018-01-01 00:00:00  to  2019-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: JFVP2SN4JAIC32EHNUUND4WR
# Sampling from  2019-01-01 00:00:00  to  2020-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: WEEE5GTWBYFSC72NK6T6AGKP
# Sampling from  2020-01-01 00:00:00  to  2021-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: 5UZ5YTZI2YO4YIMLFBEGJRGR
# Sampling from  2021-01-01 00:00:00  to  2022-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: YRUF6S3O655S7SXQGPL5B6M2
# Sampling from  2022-01-01 00:00:00  to  2023-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: VM33FJCNI7D6HMLZM54QSDQY
# Sampling from  2023-01-01 00:00:00  to  2024-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: GA22DGA7LFEZRLROVXFLZN2H
# Sampling from  2024-01-01 00:00:00  to  2025-12-31 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: GJ2KCWSIEQH5BDBSNIPTJZPJ
# Feature n°: 9/27  -- startDate: 2017-04-01 00:00:00 -- endDate: 2025-12-31 00:00:00
# ----------------------------------------------------------------------------------------------------------
# Sampling from  2017-04-01 00:00:00  to  2018-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: ARVOBTLW43ZNIS5UY7GQIOA3
# Sampling from  2018-01-01 00:00:00  to  2019-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: FOOONOUBDIU26AO524SPENEP
# Sampling from  2019-01-01 00:00:00  to  2020-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: QTHSP4H6TSQXB4CB3L7DF6YD
# Sampling from  2020-01-01 00:00:00  to  2021-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: VUE745FKAFKM37LGKRATQMIS
# Sampling from  2021-01-01 00:00:00  to  2022-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: S6CFZB6SXD6XCKCQLIFMXJYZ
# Sampling from  2022-01-01 00:00:00  to  2023-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: JAGYNHMIXQUJG2OGRSGWSREF
# Sampling from  2023-01-01 00:00:00  to  2024-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: RYV3W3XJONLJZEB7A5HPUUT7
# Sampling from  2024-01-01 00:00:00  to  2025-12-31 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: WXO3VXD5YE2PPFC2GSYXETZT
# Feature n°: 10/27  -- startDate: 2017-04-01 00:00:00 -- endDate: 2025-12-31 00:00:00
# ----------------------------------------------------------------------------------------------------------
# Sampling from  2017-04-01 00:00:00  to  2018-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: WK7HUKGYE4NCSCRNDWKFCGS5
# Sampling from  2018-01-01 00:00:00  to  2019-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: NI3EK6GEAY7QWZTBBG7MKLDI
# Sampling from  2019-01-01 00:00:00  to  2020-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: QV7PRTKAZETVPQMDC5F5DBKA
# Sampling from  2020-01-01 00:00:00  to  2021-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: 3GRMX75GNEVIXFXF2PODPHU6
# Sampling from  2021-01-01 00:00:00  to  2022-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: BIZY5DCD2WMNNXREULMQDDEL
# Sampling from  2022-01-01 00:00:00  to  2023-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: MGA4SAUUAX7PQM5ZS475BOKS
# Sampling from  2023-01-01 00:00:00  to  2024-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: LH4IJXRTUU3A5LZN6P7KAIF2
# Sampling from  2024-01-01 00:00:00  to  2025-12-31 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: Y4XLOJN5LCWUZFLEEKI5QC6M
# Feature n°: 11/27  -- startDate: 2017-04-01 00:00:00 -- endDate: 2025-12-31 00:00:00
# ----------------------------------------------------------------------------------------------------------
# Sampling from  2017-04-01 00:00:00  to  2018-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: HQAKV6YTKPVGB33MKEZY6JYG
# Sampling from  2018-01-01 00:00:00  to  2019-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: L5L4B2UQ22GMUBF4UOIVEQLW
# Sampling from  2019-01-01 00:00:00  to  2020-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: UST4PMD3DVGLYLTTYCFYY3GE
# Sampling from  2020-01-01 00:00:00  to  2021-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: V5F3HIGNHLK6I6RQTTTVKD72
# Sampling from  2021-01-01 00:00:00  to  2022-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: 63KI6D32DQTBTRRS27RDR4NR
# Sampling from  2022-01-01 00:00:00  to  2023-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: UFUUAXH2KZRB6PJ6TJ4MYTPU
# Sampling from  2023-01-01 00:00:00  to  2024-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: 7DYSTETJLQB7VZRPLEOVHJU2
# Sampling from  2024-01-01 00:00:00  to  2025-12-31 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: MAWWRW2HAA64I3MPM2C7DFP2
# Feature n°: 12/27  -- startDate: 2017-04-01 00:00:00 -- endDate: 2025-12-31 00:00:00
# ----------------------------------------------------------------------------------------------------------
# Sampling from  2017-04-01 00:00:00  to  2018-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: HG6MLUO4KSKTDU4XMZNSVYU6
# Sampling from  2018-01-01 00:00:00  to  2019-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: ATAQ7WDQFOJLTVSCQ5GADAX7
# Sampling from  2019-01-01 00:00:00  to  2020-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: LKLS5GXVHNWPMKOUV67LKVPE
# Sampling from  2020-01-01 00:00:00  to  2021-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: MSUX2RLQUM7K55C3SKZW4SYO
# Sampling from  2021-01-01 00:00:00  to  2022-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: TB74A2EQA57NJNTQSVR25Y6Y
# Sampling from  2022-01-01 00:00:00  to  2023-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: LVKC5BUG66TBHRCO7SHBVQEJ
# Sampling from  2023-01-01 00:00:00  to  2024-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: RKLDCES7UFIIAYYNHD5ITN6K
# Sampling from  2024-01-01 00:00:00  to  2025-12-31 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: KARMVKDVTLC3KUAEW2T2DZV3
# Feature n°: 13/27  -- startDate: 2017-04-01 00:00:00 -- endDate: 2025-12-31 00:00:00
# ----------------------------------------------------------------------------------------------------------
# Sampling from  2017-04-01 00:00:00  to  2018-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: S2U2XFOK7SUD52TUDAUXNTDJ
# Sampling from  2018-01-01 00:00:00  to  2019-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: ZUTYROBQLEDIQOZXUTHXC264
# Sampling from  2019-01-01 00:00:00  to  2020-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: D5LGOTGONTIZVRPW45EQT4GB
# Sampling from  2020-01-01 00:00:00  to  2021-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: 5Y3DXB5XAXNDFXAVLTSGICOG
# Sampling from  2021-01-01 00:00:00  to  2022-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: TH4OKE5WRZVFDLQGZPQQMXHJ
# Sampling from  2022-01-01 00:00:00  to  2023-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: I7GL4UGUIBHY3RY2XVIBIWDI
# Sampling from  2023-01-01 00:00:00  to  2024-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: WSFWLWXJIIIQ76W3O37T7CII
# Sampling from  2024-01-01 00:00:00  to  2025-12-31 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: YQDCGISLJL6OYW5GGEKBSJYI
# Feature n°: 14/27  -- startDate: 2017-04-01 00:00:00 -- endDate: 2025-12-31 00:00:00
# ----------------------------------------------------------------------------------------------------------
# Sampling from  2017-04-01 00:00:00  to  2018-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: KQASJAIHHV5C7WCWY7RJPY2G
# Sampling from  2018-01-01 00:00:00  to  2019-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: 2OTK5YGNBE5QWNBZFSZGNWNA
# Sampling from  2019-01-01 00:00:00  to  2020-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: KAG6ZL4RFMP256YPPQZDESXQ
# Sampling from  2020-01-01 00:00:00  to  2021-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: LHURQETUJG6T5YAMZLEZV4O7
# Sampling from  2021-01-01 00:00:00  to  2022-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: 4GK6K6I4ZM6MHS5X3GO7SKE4
# Sampling from  2022-01-01 00:00:00  to  2023-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: Y7G5XFIFZ6UQKKJTGDCRQONK
# Sampling from  2023-01-01 00:00:00  to  2024-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: T5AU3QZS3UU2JUI7A2KBQ2OA
# Sampling from  2024-01-01 00:00:00  to  2025-12-31 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: RXZYKNDFNY6VSNB4BJ5A5ERA
# Feature n°: 15/27  -- startDate: 2017-04-01 00:00:00 -- endDate: 2025-12-31 00:00:00
# ----------------------------------------------------------------------------------------------------------
# Sampling from  2017-04-01 00:00:00  to  2018-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: U3DO72V2YT5L7NMJTQABNGE5
# Sampling from  2018-01-01 00:00:00  to  2019-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: MGS5FAX2KOG2XRDQGGQ7Q6VI
# Sampling from  2019-01-01 00:00:00  to  2020-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: WGS3TFM45CRAS4HYLQZSFIJC
# Sampling from  2020-01-01 00:00:00  to  2021-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: GBPNN2G2IKZSYVQJLAYUOASX
# Sampling from  2021-01-01 00:00:00  to  2022-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: 4XQTQHIR5YU3S7IOPBAPWFKI
# Sampling from  2022-01-01 00:00:00  to  2023-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: DGI6CAEL5ZJNZM47VPHSFOPN
# Sampling from  2023-01-01 00:00:00  to  2024-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: S6PWB367B7Y5RFAZNOJ6XTIV
# Sampling from  2024-01-01 00:00:00  to  2025-12-31 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: CMX4VGTRHQXEQN7QIULXLESZ
# Feature n°: 16/27  -- startDate: 2017-04-01 00:00:00 -- endDate: 2025-12-31 00:00:00
# ----------------------------------------------------------------------------------------------------------
# Sampling from  2017-04-01 00:00:00  to  2018-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: NBSU52OEF2BS4U4IQ2KC5FXL
# Sampling from  2018-01-01 00:00:00  to  2019-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: QAXUEM3WT75PE2ISWGKG2SA3
# Sampling from  2019-01-01 00:00:00  to  2020-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: GSWGEW25ZW7ULTLUR3B3DYNM
# Sampling from  2020-01-01 00:00:00  to  2021-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: 4IQVOUHZ4SJSAMRPZLHLYKCR
# Sampling from  2021-01-01 00:00:00  to  2022-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: JFTVP2QUGPOQ7SHZCY57SVPL
# Sampling from  2022-01-01 00:00:00  to  2023-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: WRIWAJ2ENMPQU2KOS7OXJLIF
# Sampling from  2023-01-01 00:00:00  to  2024-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: THJ4A6QXCZEBHXLPRFNRC4AP
# Sampling from  2024-01-01 00:00:00  to  2025-12-31 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: AMH5Y5WUKNR3PYYYNQNFDCX5
# Feature n°: 17/27  -- startDate: 2017-04-01 00:00:00 -- endDate: 2025-12-31 00:00:00
# ----------------------------------------------------------------------------------------------------------
# Sampling from  2017-04-01 00:00:00  to  2018-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: 2KBSZBU3VAI42EFJO74FIBWE
# Sampling from  2018-01-01 00:00:00  to  2019-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: FJFKL7IVZ2NGNH6ZDUZVW7V7
# Sampling from  2019-01-01 00:00:00  to  2020-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: 5QPR6LT4ZRRM42KYLKJ5DQJN
# Sampling from  2020-01-01 00:00:00  to  2021-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: U4U6BUAYIF6LXP35OXOXLGOW
# Sampling from  2021-01-01 00:00:00  to  2022-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: LRLUNRJPPODKVWV46HVZYCFE
# Sampling from  2022-01-01 00:00:00  to  2023-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: WLDZQNXB4QEZFIDDYUE3N25M
# Sampling from  2023-01-01 00:00:00  to  2024-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: NOAPYO77ISCB5QBP4PLTS6XP
# Sampling from  2024-01-01 00:00:00  to  2025-12-31 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: WHPXZD5WHLUVXWHN2YBURMLC
# Feature n°: 18/27  -- startDate: 2017-04-01 00:00:00 -- endDate: 2025-12-31 00:00:00
# ----------------------------------------------------------------------------------------------------------
# Sampling from  2017-04-01 00:00:00  to  2018-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: FLRNCMP3Z3H5M5OYMTHPQ532
# Sampling from  2018-01-01 00:00:00  to  2019-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: WLU7OLUE6QBQ2US25C5XJ33K
# Sampling from  2019-01-01 00:00:00  to  2020-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: U7I7GFZWTSTS6RIZJC4HGWOW
# Sampling from  2020-01-01 00:00:00  to  2021-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: QNZPYH3T2USZF3QLYMDR3T4S
# Sampling from  2021-01-01 00:00:00  to  2022-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: A2MN4JF7WO7VD36AOY6Y7STB
# Sampling from  2022-01-01 00:00:00  to  2023-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: QSDLUMQ6GEXSPAHXCQICYRKU
# Sampling from  2023-01-01 00:00:00  to  2024-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: YEEMZ3TQUBMB6KKSDMOYLRWR
# Sampling from  2024-01-01 00:00:00  to  2025-12-31 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: 6FRFQFZNO2WBPRU75M6KZ2YF
# Feature n°: 19/27  -- startDate: 2017-04-01 00:00:00 -- endDate: 2025-12-31 00:00:00
# ----------------------------------------------------------------------------------------------------------
# Sampling from  2017-04-01 00:00:00  to  2018-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: NYJF637VKNHFCVCZDFMZJKSK
# Sampling from  2018-01-01 00:00:00  to  2019-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: 5VPZRVNVAB3R3RYRBNXJYRUR
# Sampling from  2019-01-01 00:00:00  to  2020-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: KHBPBOAVIB4TU3TEXWMKKAXZ
# Sampling from  2020-01-01 00:00:00  to  2021-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: X2IYG55GIQDG2US4SEMPLCTH
# Sampling from  2021-01-01 00:00:00  to  2022-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: WGKX5LG7AS2MUAJCJN5EVQ2V
# Sampling from  2022-01-01 00:00:00  to  2023-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: 32FOLDPFA3NVVWC2755OCX27
# Sampling from  2023-01-01 00:00:00  to  2024-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: 5Y4JYETFM4M552LFQCCVPLQT
# Sampling from  2024-01-01 00:00:00  to  2025-12-31 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: ALXT7OQSUB4I3JCD4XPWFQWE
# Feature n°: 20/27  -- startDate: 2017-04-01 00:00:00 -- endDate: 2025-12-31 00:00:00
# ----------------------------------------------------------------------------------------------------------
# Sampling from  2017-04-01 00:00:00  to  2018-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: KXBG7VDIDB7Z2SZRHLKE4Y2R
# Sampling from  2018-01-01 00:00:00  to  2019-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: BVNBVMVZK43PXGUFBZQRJ4YQ
# Sampling from  2019-01-01 00:00:00  to  2020-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: JZWZJH7KJQMQE72BS5DFBYQY
# Sampling from  2020-01-01 00:00:00  to  2021-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: KX6EY7HCUWSKXVXVXB2CYJGD
# Sampling from  2021-01-01 00:00:00  to  2022-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: ZIPPCJUC7LOGSOEGR5VIVG2M
# Sampling from  2022-01-01 00:00:00  to  2023-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: V2EBW4MBLLZKOAVVIMO2FXAB
# Sampling from  2023-01-01 00:00:00  to  2024-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: BF4CNGEEUCANA7JAWI6ZQBWA
# Sampling from  2024-01-01 00:00:00  to  2025-12-31 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: VKLACXFWORKK7Q4ERWKFIIU7
# Feature n°: 21/27  -- startDate: 2017-04-01 00:00:00 -- endDate: 2025-12-31 00:00:00
# ----------------------------------------------------------------------------------------------------------
# Sampling from  2017-04-01 00:00:00  to  2018-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: K7QTY3YH7BJZ7IOOLVCNKGLW
# Sampling from  2018-01-01 00:00:00  to  2019-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: DKAVN4DK3V24E3TXSYMKZBKJ
# Sampling from  2019-01-01 00:00:00  to  2020-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: JCEQIRWO6PJR4CJFMFUVN43U
# Sampling from  2020-01-01 00:00:00  to  2021-01-01 00:00:00
# ['date', 'QC', 'longitude', 'latitude', 's2cloudless_probability', 'estimateLAI', 'partition', 'networkID', 'errorLAI']
# Export task started with ID: HYTBZ7ZYWGHAAD4AA53KA4WF
# Sampling from  2021-01-01 00:00:00  to  2022-01-01 00:00:00

# %%
# Function definition
#
# LEAF.imageSites
# def imageSites(siteList,
#                 imageCollectionName,
#                 sensorName,
#                 outputPath,
#                 algorithm,
#                 variableName='Surface_Reflectance',
#                 featureRange=[0,np.nan],
#                 maxCloudcover=100,
#                 outputScale=30,
#                 exportFlag='Asset',
#                 prefixProperty='system:index',
#                 inputScale=30,
#                 bufferSpatialSize=0,
#                 subsamplingFraction=1,
#                 numPixels=0,
#                 bufferTemporalSize=[0,0],
#                 calendarRange=[1,12,'month'],
#                 timeZone='Etc/GMT+6',
#                 shardSize='ys',
#                 exportDataType='float'
#                 ):
#
# Applies a LEAF toolbox algorithm to map a canopy variable for all clear sky unmasked pixels from an input image collection
# falling within the spatial and temporal extents of features in a list of sites.  The spatial extent of features is defined by their GEE geometry.  
# The temporal extent of features is defined by their "system:time_start" and "system:time_end" properties or user defined otherwise.
#
# Parameters:
#
# siteList: list of readable GEE feature collection assets.  Features must have a system:time_start and system:time_end property.
# sensorName: user provided name of sensor for output file name
# imageCollectionName: input image collection name from one of the list defined by GEE
#                 ["COPERNICUS/S2_SR_HARMONIZED","COPERNICUS/S2_SR_HARMONIZED_10m","LANDSAT/LC08/C02/T1_L2","LANDSAT/LC09/C02/T1_L2","NASA/HLS/HLSL30/v002"]
# outputPath: google drive , cloud or gee asset folder (for cloud or asset it must exist)
# algorithm: python module specifying LEAF algorithm to apply , currently one of list ["SL2PV0","SL2PV1"]
# variableName: variable to be mapped from one of the list ["ALBEDO","FAPAR","FCOVER","LAI","CWC","CCC","DASF"] defined by https://github.com/rfernand387/LEAF-Toolbox/wiki/Visualisation-Outputs              
# feature_range: range of features in each site GEE feature collection to sample, use this if you have one site with many features and want only a few of them                                                                                                                        
# maxCloudCover: maximum input image cloud cover percentage [0,100]
# outputScale: output pixel size (m)
# exportFlag: export destination (Local,Drive,Asset,CloudStorage) , dont use Local unless it is a small job
# prefixProperty: the property of the sampling features to use for file name prefix
# inputScale: input pixel size (m)
# bufferSpatialSize: width (m) of spatial buffer applied to features prior to sampling
# bufferTemporalSize: dilation (d) of start and end time of sampled features OR temporal interval ["YYYY-MM-DD","YYYY-MM-DD"[ of start and end of time interval to sample.  
# subsamplingFraction: fraction (0 to 1) of pixels to sample within a feature on any given image
# numPixels: maximum number of pixels to sample within a feature, overrides subsampling fraction
# geometries: export the geometry of the sampling feature
# calendarRange: months within each year to sample, inclusive
# timeZone: time zone for sampling if desired, otherwise UTC
# shardSize: temporal interval of shards for output files, e.g. annual
#
# Output:
#
# Drive,Asset,CloudStorage: .csv file with one row per sampled output pixel per day
# Local: Results in a .pkl file with a pandas dictionary for each site in siteList:
#
# sitesDictionary: dictionary with keys corresponding to sites and structure.  The value of each key is a dictionary with two keys:
#                     'feature' : properties of the sampled feature
#                     'SL2PV0' or 'SL2PV1' : a pandas data frame where columns correspond to algorithm output properties and rows correspond to a retrieval within the time and spatial interval of the feature               
#
# Example:
#S2LAIV0_2025= LEAFv4.sampleSites(siteList, 
# sensorName = 'S2', 
# imageCollectionName="COPERNICUS/S2_SR_HARMONIZED",
# outputPath='leafoutput13',
# algorithm=SL2PV0, 
# variableName="LAI",
# featureRange=[0,999], 
# maxCloudcover=20,
# outputScale=20,
# exportFlag='Drive',
# prefixProperty='system:index',
# inputScale=20,
# bufferSpatialSize=0,
# subsamplingFraction=1,
# numPixels=0,
# geometries=False,
# bufferTemporalSize=['2017-04-01','2025-12-31'],
# calendarRange=[6,9,'month'],
# timeZone='Etc/GMT+6',
# shardSize='YS')
#

# %%
HLSL30LAIV0_2025= LEAFv4.imageSites(siteList, \
                                    imageCollectionName="COPERNICUS/S2_SR_HARMONIZED",\
                                    sensorName = 'S2', \
                                    outputPath='leafoutput8',\
                                    algorithm=SL2PV0, \
                                    variableName="LAI",\
                                    featureRange=[0,1], \
                                    maxCloudcover=80,\
                                    outputScale=20,\
                                    exportFlag='CloudStorage',
                                    prefixProperty='system:index',
                                    inputScale=20,
                                    bufferSpatialSize=4000,
                                    bufferTemporalSize=['2020-07-01','2021-09-01'],
                                    calendarRange=[7,8,'month'],
                                    timeZone='Etc/GMT+6',
                                    shardSize='YS')
# Out:
# STARTING LEAF.imageSites using  COPERNICUS/S2_SR_HARMONIZED
# S2
# Site:  projects/ee-modis250/assets/2bt/Bonney_SiteswithDates_2019  with  27  features.
# Processing Features: from 0 to 1
# Feature n°: 0/1  -- startDate: 2020-07-01 00:00:00 -- endDate: 2021-09-01 00:00:00
# ----------------------------------------------------------------------------------------------------------
# Sampling from  2020-07-01 00:00:00  to  2021-09-01 00:00:00
# Export task started with ID: AGXLKEP5L7DR6XAYMNJBEKES
# Export task started with ID: MVJIZUIXFSIW7B4WBH54HEOP
# Export task started with ID: JRSP6OZCAMNRGZA7KESU5DFC
# Export task started with ID: WOBX6Q4A3JLMECCBPKNAAJBU
# Export task started with ID: 2NRJVRUIM2WBWFC42IN7QAYZ
# Export task started with ID: 735HTJT3NRXUIV6XADOL3SS5
# Export task started with ID: CHXWSZW5CZRBUW6FGT2ZUMOM
# Export task started with ID: XLSVL3ZTETL6RMYRB7C7PGMD
# Export task started with ID: VFRR2KQD5LSVAG56QZNUG6TN
# Export task started with ID: M3BQXMG5QYC6LW6IFYSQZ32P
# Export task started with ID: BKGHXBGGXITZPTBZDOWYQYLV
# Export task started with ID: LT2RRLLCSE25RZQWIE2MQ3W2
# Export task started with ID: DK725EWKWQKICCORNPC4XX2D
# Export task started with ID: ESC3KTKXG7RM5VEYIN72RSWO
# Export task started with ID: QKCWMTLZABWTX5AQCL6GS7HN
# Export task started with ID: VY25YKAYRZZGERQOU4ALKZ4I
# Export task started with ID: MZ2Z4AK2B3IICOHXM46BWKZF
# Export task started with ID: UN5RKRGZZ76F7ZP7375QY6JJ
# Export task started with ID: 3ZDPZUAAWHKDDEDVXBU7AQFN
#
# DONE LEAF.sites
